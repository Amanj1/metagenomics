# %%
import os
import glob
import re
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random

# %%
#df=pd.read_csv('/home/amanj/Documents/Results_from_pipeline/bbmap_results_TTV/all_TTV_results/All_TTV_1to6.tsv', sep='\t').sort_values(by=['SampleID'], ascending=False)
#df1=pd.read_csv('/home/amanj/Documents/Results_from_pipeline/bbmap_results_TTV/all_TTV_results/All_TTV_1to6.tsv', sep='\t').drop(['pct_mapped'], axis=1).groupby(by=['SampleID','Type']).sum().reset_index()

#df=pd.read_csv('/home/amanj/Documents/Results_from_pipeline/bbmap_results_TTV/all_TTV_results/All_TTV_reference_7to13/All_TTV_7to13.tsv', sep='\t').sort_values(by=['SampleID'], ascending=False)
#df1=pd.read_csv('/home/amanj/Documents/Results_from_pipeline/bbmap_results_TTV/all_TTV_results/All_TTV_reference_7to13/All_TTV_7to13.tsv', sep='\t').drop(['pct_mapped'], axis=1).groupby(by=['SampleID','Type']).sum().reset_index()

#df=pd.read_csv('/home/amanj/Documents/Results_from_pipeline/bbmap_results_TTV/all_TTV_results/All_TTV_reference_14to20/All_TTV_14to20.tsv', sep='\t').sort_values(by=['SampleID'], ascending=False)
#df1=pd.read_csv('/home/amanj/Documents/Results_from_pipeline/bbmap_results_TTV/all_TTV_results/All_TTV_reference_14to20/All_TTV_14to20.tsv', sep='\t').drop(['pct_mapped'], axis=1).groupby(by=['SampleID','Type']).sum().reset_index()

#df=pd.read_csv('/home/amanj/Documents/Results_from_pipeline/bbmap_results_TTV/all_TTV_results/All_TTV_reference_21to24/All_TTV_21to24.tsv', sep='\t').sort_values(by=['SampleID'], ascending=False)
#df1=pd.read_csv('/home/amanj/Documents/Results_from_pipeline/bbmap_results_TTV/all_TTV_results/All_TTV_reference_21to24/All_TTV_21to24.tsv', sep='\t').drop(['pct_mapped'], axis=1).groupby(by=['SampleID','Type']).sum().reset_index()

df=pd.read_csv('/home/amanj/Documents/Results_from_pipeline/bbmap_results_TTV/all_TTV_results/All_TTV_reference_25to29/All_TTV_25to29.tsv', sep='\t').sort_values(by=['SampleID'], ascending=False)
df1=pd.read_csv('/home/amanj/Documents/Results_from_pipeline/bbmap_results_TTV/all_TTV_results/All_TTV_reference_25to29/All_TTV_25to29.tsv', sep='\t').drop(['pct_mapped'], axis=1).groupby(by=['SampleID','Type']).sum().reset_index()

col_name =df1.columns[1]
df1=df1.rename(columns = {col_name:'Reference'})

# %%
print(df1)

# %%
print(df)
df1.select("Reference").show()

# %%
#print(df1['n_mapped'])

# %%
#df2 = df1[df1.Reference == "1-TA278"]
#df3 = df1[df1.Reference == "2-CH71"]
#df4 = df1[df1.Reference == "3-HEL32"]
#df5 = df1[df1.Reference == "4-Pt-TTV6"]
#df6 = df1[df1.Reference == "5-TCHN-C1"]
#df7 = df1[df1.Reference == "6-KAV"]

#df8 = df1[df1.Reference == "7-PMV"]
#df9 = df1[df1.Reference == "8-Kt-08F"]
#df10 = df1[df1.Reference == "9-BM1C-18"]
#df11 = df1[df1.Reference == "10-JT34F"]
#df12 = df1[df1.Reference == "11-TCHN-D1"]
#df13 = df1[df1.Reference == "12-CT44F"]
#df14 = df1[df1.Reference == "13-TCHN-A"]

#df15 = df1[df1.Reference == "14-CH65-1"]
#df16 = df1[df1.Reference == "15-TJN01"]
#df17 = df1[df1.Reference == "16-TUS01"]
#df18 = df1[df1.Reference == "17-SENV-G"]
#df19 = df1[df1.Reference == "18-SENV-C"]
#df20 = df1[df1.Reference == "19-SANBAN"]
#df21 = df1[df1.Reference == "20-SAa-10"]

#df22 = df1[df1.Reference == "21-TCHN-B"]
#df23 = df1[df1.Reference == "22-svi-1"]
#df24 = df1[df1.Reference == "23-CH65-2"]
#df25 = df1[df1.Reference == "24-SAa-01"]

df26 = df1[df1.Reference == "25-Mf-TTV9"]
df27 = df1[df1.Reference == "26-Mf-TTV3"]
df28 = df1[df1.Reference == "27-CT23F"]
df29 = df1[df1.Reference == "28-CT43F"]
df30 = df1[df1.Reference == "29-yonKC009"]

# %%
#df1.Reference == "CMI1.252"
print(df2)
print(df3)

# %%
#fig, axes = plt.subplots(nrows=4, ncols=2)

df2.plot.bar("SampleID","n_mapped")
df3.plot.bar("SampleID","n_mapped")
df4.plot.bar("SampleID","n_mapped")
df5.plot.bar("SampleID","n_mapped")
df6.plot.bar("SampleID","n_mapped")
df7.plot.bar("SampleID","n_mapped")
df8.plot.bar("SampleID","n_mapped")
df9.plot.bar("SampleID","n_mapped")
df10.plot.bar("SampleID","n_mapped")
df11.plot.bar("SampleID","n_mapped")
df12.plot.bar("SampleID","n_mapped")
df13.plot.bar("SampleID","n_mapped")
df14.plot.bar("SampleID","n_mapped")
df15.plot.bar("SampleID","n_mapped")
df16.plot.bar("SampleID","n_mapped")
df17.plot.bar("SampleID","n_mapped")
df18.plot.bar("SampleID","n_mapped")
df19.plot.bar("SampleID","n_mapped")
df20.plot.bar("SampleID","n_mapped")
df21.plot.bar("SampleID","n_mapped")
df22.plot.bar("SampleID","n_mapped")
df23.plot.bar("SampleID","n_mapped")
df24.plot.bar("SampleID","n_mapped")
df25.plot.bar("SampleID","n_mapped")
df26.plot.bar("SampleID","n_mapped")
df27.plot.bar("SampleID","n_mapped")
df28.plot.bar("SampleID","n_mapped")
df29.plot.bar("SampleID","n_mapped")
df30.plot.bar("SampleID","n_mapped")
#df2.plot.bar
#plt.show()

# %%
#?df2.plot
#fig, ax = plt.subplots()
#df1.groupby('Reference').plot.line(x='SampleID', y='n_mapped', ax=ax, legend=True)
plt.figure(figsize=(16, 6))
plotFig = sns.lineplot('SampleID', 'n_mapped', data=df1, hue ='Reference')
for item in plotFig.get_xticklabels():
    item.set_rotation(60)

# %%
plt.figure(figsize=(16, 6))
plotFig = sns.barplot('SampleID', 'n_mapped', data=df1, hue ='Reference')
for item in plotFig.get_xticklabels():
    item.set_rotation(90)

# %%
# ?df1.plot.line

# %%
plt.figure(figsize=(16, 6))
plotFig = sns.scatterplot('SampleID', 'n_mapped', data=df1, hue ='Reference',s=150, alpha=1)
#sns.regplot(x=df1['SampleID'], y=df1["n_mapped"], fit_reg=False, scatter_kws={"color":"darkred","alpha":0.3,"s":200} )

for item in plotFig.get_xticklabels():
    item.set_rotation(90)

# %%
plt.figure(figsize=(16, 6))
random.seed( 10 )
plotFig = sns.stripplot('SampleID', 'n_mapped', data=df1, hue ='Reference',s=11, alpha=0.4,jitter=0.4)

for item in plotFig.get_xticklabels():
    item.set_rotation(90)

# %%
#fig = plt.figure(figsize=(16, 6))
f, axes = plt.subplots(4, 2, sharey=True, figsize=(26, 20))
f.subplots_adjust(top=4)

#25 to 29
g24= sns.barplot('SampleID', 'n_mapped', data=df26, hue ='Reference', ax=axes[0][0])
for item in g24.get_xticklabels():
    item.set_rotation(90)
g25= sns.barplot('SampleID', 'n_mapped', data=df27, hue ='Reference', ax=axes[0][1])
for item in g25.get_xticklabels():
    item.set_rotation(90)
g26= sns.barplot('SampleID', 'n_mapped', data=df28, hue ='Reference', ax=axes[1][0])
for item in g26.get_xticklabels():
    item.set_rotation(90)
g27= sns.barplot('SampleID', 'n_mapped', data=df29, hue ='Reference', ax=axes[1][1])
for item in g27.get_xticklabels():
    item.set_rotation(90)
g28= sns.barplot('SampleID', 'n_mapped', data=df30, hue ='Reference', ax=axes[2][0])
for item in g28.get_xticklabels():
    item.set_rotation(90)

# %%
#1 to 6
g= sns.barplot('SampleID', 'n_mapped', data=df2, hue ='Reference', ax=axes[0][0])
for item in g.get_xticklabels():
    item.set_rotation(90)
g1= sns.barplot('SampleID', 'n_mapped', data=df3, hue ='Reference', ax=axes[0][1])
for item in g1.get_xticklabels():
    item.set_rotation(90)
g2= sns.barplot('SampleID', 'n_mapped', data=df4, hue ='Reference', ax=axes[1][0])
for item in g2.get_xticklabels():
    item.set_rotation(90)
g3= sns.barplot('SampleID', 'n_mapped', data=df5, hue ='Reference', ax=axes[1][1])
for item in g3.get_xticklabels():
    item.set_rotation(90)
g4= sns.barplot('SampleID', 'n_mapped', data=df6, hue ='Reference', ax=axes[2][0])
for item in g4.get_xticklabels():
    item.set_rotation(90)
g5= sns.barplot('SampleID', 'n_mapped', data=df7, hue ='Reference', ax=axes[2][1])
for item in g5.get_xticklabels():
    item.set_rotation(90)

#7 to 13
g6= sns.barplot('SampleID', 'n_mapped', data=df8, hue ='Reference', ax=axes[0][0])
for item in g6.get_xticklabels():
    item.set_rotation(90)
g7= sns.barplot('SampleID', 'n_mapped', data=df9, hue ='Reference', ax=axes[0][1])
for item in g7.get_xticklabels():
    item.set_rotation(90)
g8= sns.barplot('SampleID', 'n_mapped', data=df10, hue ='Reference', ax=axes[1][0])
for item in g8.get_xticklabels():
    item.set_rotation(90)
g9= sns.barplot('SampleID', 'n_mapped', data=df11, hue ='Reference', ax=axes[1][1])
for item in g9.get_xticklabels():
    item.set_rotation(90)
g10= sns.barplot('SampleID', 'n_mapped', data=df12, hue ='Reference', ax=axes[2][0])
for item in g10.get_xticklabels():
    item.set_rotation(90)
g11= sns.barplot('SampleID', 'n_mapped', data=df13, hue ='Reference', ax=axes[2][1])
for item in g11.get_xticklabels():
    item.set_rotation(90)
g12= sns.barplot('SampleID', 'n_mapped', data=df14, hue ='Reference', ax=axes[3][0])
for item in g12.get_xticklabels():
    item.set_rotation(90)    
    
#14 to 20
g13= sns.barplot('SampleID', 'n_mapped', data=df15, hue ='Reference', ax=axes[0][0])
for item in g13.get_xticklabels():
    item.set_rotation(90)
g14= sns.barplot('SampleID', 'n_mapped', data=df16, hue ='Reference', ax=axes[0][1])
for item in g14.get_xticklabels():
    item.set_rotation(90)
g15= sns.barplot('SampleID', 'n_mapped', data=df17, hue ='Reference', ax=axes[1][0])
for item in g15.get_xticklabels():
    item.set_rotation(90)
g16= sns.barplot('SampleID', 'n_mapped', data=df18, hue ='Reference', ax=axes[1][1])
for item in g16.get_xticklabels():
    item.set_rotation(90)
g17= sns.barplot('SampleID', 'n_mapped', data=df19, hue ='Reference', ax=axes[2][0])
for item in g17.get_xticklabels():
    item.set_rotation(90)
g18= sns.barplot('SampleID', 'n_mapped', data=df20, hue ='Reference', ax=axes[2][1])
for item in g18.get_xticklabels():
    item.set_rotation(90)
g19= sns.barplot('SampleID', 'n_mapped', data=df21, hue ='Reference', ax=axes[0][0])
for item in g19.get_xticklabels():
    item.set_rotation(90)

#21 to 24
g20= sns.barplot('SampleID', 'n_mapped', data=df22, hue ='Reference', ax=axes[0][0])
for item in g20.get_xticklabels():
    item.set_rotation(90)
g21= sns.barplot('SampleID', 'n_mapped', data=df23, hue ='Reference', ax=axes[0][1])
for item in g21.get_xticklabels():
    item.set_rotation(90)
g22= sns.barplot('SampleID', 'n_mapped', data=df24, hue ='Reference', ax=axes[1][0])
for item in g22.get_xticklabels():
    item.set_rotation(90)
g23= sns.barplot('SampleID', 'n_mapped', data=df25, hue ='Reference', ax=axes[1][1])
for item in g23.get_xticklabels():
    item.set_rotation(90)
